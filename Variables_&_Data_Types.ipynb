# %% [markdown]
# <a href="https://colab.research.google.com/github/Divthiyagu/EduBoard/blob/main/Variables_%26_Data_Types.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Divya"
age = 22
height = 5.4
is_Employee = True
print(type(name))
print(type(age))
print(type(height))
print(type(is_Employee))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
